# %%
# 1. 라이브러리 설치 (안 되어 있다면)
# !pip install wandb

# 2. 로그인 명령어 실행
# !wandb login
# Out:
# ...
# wandb: Logging into https://api.wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: Find your API key here: https://wandb.ai/authorize?ref=models
# wandb: Paste an API key from your profile and hit enter:
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: W&B API key is configured. Use `wandb login --relogin` to force relogin

# %%
pip install ultralytics roboflow
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 20.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.9/89.9 kB 9.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 6.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 41.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 87.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 79.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.12.0.88
#     Uninstalling opencv-python-headless-4.12.0.88:
#       Successfully uninstalled opencv-python-headless-4.12.0.88
#   Attempting uninstall: idna
#     Found existing installation: idna 3.11
#     Uninstalling idna-3.11:
#       Successfully uninstalled idna-3.11
# ...

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="DaDo5dURQRX43RGzMUq8")
project = rf.workspace("test-wrkdf").project("bdd100k-finetune")
version = project.version(3)
dataset = version.download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to bdd100k-finetune-3 in yolov8:: 100%|██████████| 63810/63810 [00:06<00:00, 9704.52it/s]
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
from ultralytics import RTDETR
import wandb

wandb.init(project='bdd_rtdetr', name='run_01')

# 1. 모델 로드
# rtdetr-l.pt (Large) 또는 rtdetr-x.pt (X-Large) 선택 가능
# 처음엔 coco 데이터로 사전학습된 가중치를 자동으로 다운로드합니다.
model = RTDETR('rtdetr-l.pt')

# 2. 학습 시작
# data 인자에는 위에서 다운로드 받은 폴더 안의 'data.yaml' 경로를 넣으세요.
results = model.train(
    data='/content/bdd100k-finetune-3/data.yaml',  # [수정 필요] 데이터셋 내의 yaml 파일 경로
    epochs=20,             # 학습 에폭 수
    imgsz=640,             # 이미지 크기 (보통 640)
    batch=16,              # 배치 사이즈 (메모리 부족시 8이나 4로 줄이세요)
    project='bdd_rtdetr',  # 프로젝트 이름 (결과 저장 폴더명)
    name='run_01',         # 실험 이름
    device=0               # GPU 번호 (0번)
)

wandb.finish()
# Out:
# invalid escape sequence '\/'
# wandb: W&B API key is configured. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.23.1
# Run data is saved locally in <code>/content/wandb/run-20260112_023635-5mzsyd5h</code>
# Syncing run <strong><a href='https://wandb.ai/woojeong321-academy/bdd_rtdetr/runs/5mzsyd5h' target="_blank">run_01</a></strong> to <a href='https://wandb.ai/woojeong321-academy/bdd_rtdetr' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/woojeong321-academy/bdd_rtdetr' target="_blank">https://wandb.ai/woojeong321-academy/bdd_rtdetr</a>
#  View run at <a href='https://wandb.ai/woojeong321-academy/bdd_rtdetr/runs/5mzsyd5h' target="_blank">https://wandb.ai/woojeong321-academy/bdd_rtdetr/runs/5mzsyd5h</a>
# ...
# Ultralytics 8.3.252 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# ...

# %%
import shutil
import os
from google.colab import drive

# 1. 구글 드라이브 마운트 (이미 했다면 생략 가능)
drive.mount('/content/drive')

# 2. 저장할 경로 설정 (본인의 드라이브 폴더명으로 수정하세요)
destination_folder = '/content/drive/MyDrive/BDD_Project/Models'

# 폴더가 없으면 생성
if not os.path.exists(destination_folder):
    os.makedirs(destination_folder)

# 3. best.pt 파일 복사
source_path = 'bdd_rtdetr/run_01/weights/best.pt' # 학습 코드의 project/name 경로 확인
target_path = os.path.join(destination_folder, 'rtdetr_bdd_best.pt')

shutil.copy(source_path, target_path)

print(f"모델이 구글 드라이브에 저장되었습니다: {target_path}")
# Out:
# Mounted at /content/drive
# 모델이 구글 드라이브에 저장되었습니다: /content/drive/MyDrive/BDD_Project/Models/rtdetr_bdd_best.pt

# %%
import torch
print(f"CUDA 사용 가능 여부: {torch.cuda.is_available()}")
# 결과가 True 여야 학습이 가능합니다.
# Out:
# CUDA 사용 가능 여부: True
